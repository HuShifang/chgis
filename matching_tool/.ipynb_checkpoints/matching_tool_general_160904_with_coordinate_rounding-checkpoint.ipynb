# %%
#! /usr/bin/python3

# Script for comparing an input .csv file with an existing .csv file (e.g. the current CHGIS).
# Indicates 1) matches on name and 2) strength of match on content
# Requires the library 'pandas' to be installed, which is included in Anaconda's free Python distribution

# by Stephen Ford (stephen.p.ford@gmail.com) on 2016-09-01

import pandas as pd
import os.path 
import numpy as np
import math

# %%
# function for selecting .csv files for manipulation

def csv_picker():
    ''' Function for checking whether user input path 1) is that of a valid file, and 2) is of a file ending with '.csv'
        Prompts for re-entry if entry is invalid.
        Returns a pandas DataFrame constructed from the valid .csv file
    '''
    name = input()

    # checking that the path is a valid filename, and prompting for re-entry if not
    while not (os.path.isfile(name)):
        print("Not a valid filename.  Please try again, or use Ctrl-C to exit:")
        name = input()
        
    # checking that the valid filename ends in .csv, prompting for re-entry if not
    while not name.endswith('.csv'):
        print("Filename does not end in .csv -- please try again or use Ctrl-C to exit:")
        name = input()

    print("\nThank you -- filename %s is valid.\n" % name)       
    return pd.read_csv(name, low_memory=False)

# %%
# soliciting files for comparison; presumption is that second file entered will be the CHGIS v5 in .csv format
print("Please input the path of the .csv file (with extension) you wish to compare with the CHGIS:")
new_data = csv_picker()
# /home/sf/chgis/input/sample_data/Donghan_2014-10-02_copy.csv

print("Please input the path of the .csv file (with extension) containing CHGIS data (script expects v5, or at least its column names):")
chgis = csv_picker()
# /home/sf/chgis/input/v5_augment_2016-08-09.csv
# Out:
# Please input the path of the .csv file (with extension) you wish to compare with the CHGIS:
# /home/sf/chgis/input/sample_data/Donghan_2014-10-02_copy.csv
#
# Thank you -- filename /home/sf/chgis/input/sample_data/Donghan_2014-10-02_copy.csv is valid.
#
# Please input the path of the .csv file (with extension) containing CHGIS data (script expects v5, or at least its column names):
# /home/sf/chgis/input/v5_augment_2016-08-09.csv
#
# Thank you -- filename /home/sf/chgis/input/v5_augment_2016-08-09.csv is valid.

# %%
# function for mapping the input .csv's fields to the desired, standardized output fields
def field_mapper(output_field, frame=new_data):
    ''' Function that will prompt user to manually map fields of the input .csv to standardized output fields.
        Name changes will be made in-place (i.e. in the DataFrame -- the .csv will be untouched).
        If user fails to enter anything for the given mapping, the output field will be present in the output 
        file, but have no values.        
    '''
    
    print("\nPlease enter the field in the incoming non-CHGIS .csv that will be labeled '%s' in the output .csv:" % output_field)
    input_field = input()
    
    # prompts for re-entering the input field if 1) it is not one of the column names and 2) it isn't an empty string
    while (not input_field in list(new_data.columns.values)) and (input_field):
        print("\nNot a valid column name.  Please try again:")
        input_field = input()
        
    # simply exit if the user pressed enter, bypassing the mapping, or perform the mapping if a valid field name has been entered
    if input_field:
        frame.rename(columns={input_field:output_field}, inplace=True)
    else:
        frame[output_field] = ''

# %%
# declaring the list of output .csv field names that will derive from the new data
# i.e., all those fields whose names will be 'input_*' in the final .csv

input_fields = [   
    'input_id',
    'input_nm_py',
    'input_nm_simp',
    'input_nm_trad',
    'input_type',
    'input_year_beg',
    'input_year_end',
    'input_dynasty',
    'input_other_id',
    'input_prnt',
    'input_obj_type',
    'input_x_coord',
    'input_y_coord'
]

# %%
# renaming fields in the new data DataFrame to conform to specifications

for field in input_fields:
    field_mapper(field)
# Out:
# Please enter the field in the incoming non-CHGIS .csv that will be labeled 'input_id' in the output .csv:
# 規範碼
#
# Please enter the field in the incoming non-CHGIS .csv that will be labeled 'input_nm_py' in the output .csv:
#
#
# Please enter the field in the incoming non-CHGIS .csv that will be labeled 'input_nm_simp' in the output .csv:
#
#
# Please enter the field in the incoming non-CHGIS .csv that will be labeled 'input_nm_trad' in the output .csv:
# 县名
#
# Please enter the field in the incoming non-CHGIS .csv that will be labeled 'input_type' in the output .csv:
#
#
# Please enter the field in the incoming non-CHGIS .csv that will be labeled 'input_year_beg' in the output .csv:
# BEG
#
# Please enter the field in the incoming non-CHGIS .csv that will be labeled 'input_year_end' in the output .csv:
# END
#
# Please enter the field in the incoming non-CHGIS .csv that will be labeled 'input_dynasty' in the output .csv:
# 朝代
#
# Please enter the field in the incoming non-CHGIS .csv that will be labeled 'input_other_id' in the output .csv:
# 舊規範碼
#
# Please enter the field in the incoming non-CHGIS .csv that will be labeled 'input_prnt' in the output .csv:
# 屬
#
# Please enter the field in the incoming non-CHGIS .csv that will be labeled 'input_obj_type' in the output .csv:
#
#
# Please enter the field in the incoming non-CHGIS .csv that will be labeled 'input_x_coord' in the output .csv:
# 經度
#
# Please enter the field in the incoming non-CHGIS .csv that will be labeled 'input_y_coord' in the output .csv:
# 緯度

# %%
# dropping all fields from the new_data DataFrame that won't be in final output
new_data = new_data[input_fields]

# %%
# manually renaming one exception to the following pattern
chgis.rename(columns={'src':'data_source'}, inplace=True)

# renaming the CHGIS fields in-place to conform to output specifications
chgis.columns = ['tgaz_%s' % x for x in chgis.columns]

# %%
# offering user choice of strict or fuzzy name-matching

def merge_chooser():
    ''' Function called only if the user selects to merge on traditional characters 繁體字 or simplified characters 简体字
        Lets user choose whether to do a strict or fuzzy merge.
        In a fuzzy merge, only the first two characters of the Chinese names will be checked against one another.
    '''
    print('''
        Please indicate, by entering a numerical digit 1-2, whether you wish to do a strict or fuzzy match of names:
        1. Strict matching (e.g. '張掖' matches '張掖', but '張掖' does not match '張掖居延屬國')
        2. Fuzzy matching (e.g. '張掖' matches '張掖', and '張掖' also matches '張掖居延屬國')
        ''')

    accepted = False
    choice = input()

    while accepted == False:
        if choice == '1':
            print('Proceeding with strict matching of names.')
            accepted = True
            mode = 'strict'
            df = chgis.merge(new_data, how='outer', left_on=chgis_name_match_field, right_on=input_name_match_field, indicator=True)
            return df, mode
        elif choice == '2':
            print('Proceeding with fuzzy matching of names.')
            accepted = True
            mode = 'fuzzy'
            chgis['fuzzy_nm'] = chgis[chgis_name_match_field].map(lambda x: x[:2])
            new_data['fuzzy_nm'] = new_data[input_name_match_field].map(lambda x: x[:2])
            df = chgis.merge(new_data, how='outer', on='fuzzy_nm', indicator=True)
            return df, mode
        else:
            print("\nNot a valid response.  Please try again:\n")
            choice = input()

# %%
# soliciting user choice regarding which name field to take as primary
print(
    '''
    Thank you. Now, please indicate, by entering a numerical digit 1-3, which of the following names you wish to make the primary key for comparing data:
    1. Name in complex/traditional Chinese characters 繁体字
    2. Name in simplified Chinese characters 简体字
    3. Name in pinyin 拼音
    '''
)

accepted = False
choice = input()

while accepted == False:
    if choice == '1':
        print("\nUsing name in complex/traditional Chinese characters 繁体字 as primary key.")
        accepted = True
        input_name_match_field = 'input_nm_trad'
        chgis_name_match_field = 'tgaz_nm_trad'
        output_name_match_field = 'out_nm_trad_match'
        df, mode = merge_chooser()
        
    elif choice == '2':
        print("\nUsing name in simplified Chinese characters 简体字 as primary key.")
        accepted = True
        input_name_match_field = 'input_nm_simp'
        chgis_name_match_field = 'tgaz_nm_simp'
        output_name_match_field = 'out_nm_simp_match'
        df, mode = merge_chooser()
    elif choice == '3':
        print("\nUsing name in pinyin 拼音 as primary key.")
        accepted = True
        input_name_match_field = 'input_nm_py'
        chgis_name_match_field = 'tgaz_nm_py'
        output_name_match_field = 'out_nm_py_match'
        mode = 'strict'
        print('Fuzzy matching is not currently supported for pinyin names.  Proceeding with strict matching.')
        df = chgis.merge(new_data, how='outer', left_on=chgis_name_match_field, right_on=input_name_match_field, indicator=True)
    else:
        print("\nNot a valid response.  Please try again:\n")
        choice = input()
# Out:
#     Thank you. Now, please indicate, by entering a numerical digit 1-3, which of the following names you wish to make the primary key for comparing data:
#     1. Name in complex/traditional Chinese characters 繁体字
#     2. Name in simplified Chinese characters 简体字
#     3. Name in pinyin 拼音
#
# 1
#
# Using name in complex/traditional Chinese characters 繁体字 as primary key.
#
#         Please indicate, by entering a numerical digit 1-2, whether you wish to do a strict or fuzzy match of names:
#         1. Strict matching (e.g. '張掖' matches '張掖', but '張掖' does not match '張掖居延屬國')
#         2. Fuzzy matching (e.g. '張掖' matches '張掖', and '張掖' also matches '張掖居延屬國')
#
# 2
# Proceeding with fuzzy matching of names.
# /home/sf/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# removing rows that are only present in the CHGIS file
df = df[df['_merge'] != 'left_only']

# %%
# asking user if they want to do strict or fuzzy matching on spatial coordinates
print('''
    Please indicate, by entering a numerical digit 1-2, whether you wish to do a strict or fuzzy match of spatial coordinates:
    1. Strict matching (requires exact match, e.g. '119.94656' does NOT match '119.946560', '120.00432', or '119.89441')
    2. Fuzzy matching (only requires rounded number of whole degrees matches, e.g. '119.64656' DOES match '119.946560', '120.00432', and '119.89441')
    ''')

accepted = False
choice = input()

while accepted == False:
    if choice == '1':
        print('Proceeding with strict matching of spatial coordinates.')
        accepted = True
        df['out_x_coord_match'] = df['input_x_coord'] == df['tgaz_x_coord']
        df['out_y_coord_match'] = df['input_y_coord'] == df['tgaz_y_coord']

    elif choice == '2':
        print('Proceeding with fuzzy matching of spatial coordinates.')
        accepted = True
        df['out_x_coord_match'] = df['input_x_coord'].map(lambda x: round(x) if type(x) == float else False) == df['tgaz_x_coord'].map(lambda x: round(x) if type(x) == float else False)
        df['out_y_coord_match'] = np.where(np.isnan(df['input_y_coord']) or np.isnan(df['tgaz_y_coord']), 'NaN', df['input_y_coord'].map(lambda y: round(y)) == df['tgaz_y_coord'].map(lambda y: round(y)))

    else:
        print("\nNot a valid response.  Please try again:\n")
        choice = input()
# Out:
#     Please indicate, by entering a numerical digit 1-2, whether you wish to do a strict or fuzzy match of spatial coordinates:
#     1. Strict matching (requires exact match, e.g. '119.94656' does NOT match '119.946560', '120.00432', or '119.89441')
#     2. Fuzzy matching (only requires rounded number of whole degrees matches, e.g. '119.64656' DOES match '119.946560', '120.00432', and '119.89441')
#
# 2
# Proceeding with fuzzy matching of spatial coordinates.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-714d5dd56b0f> in <module>()
#      19         print('Proceeding with fuzzy matching of spatial coordinates.')
#      20         accepted = True
# ---> 21         print(type(df['input_x_coord'][3]))
#      22         df['out_x_coord_match'] = df['input_x_coord'].map(lambda x: round(x) if type(x) == float else False) == df['tgaz_x_coord'].map(lambda x: round(x) if type(x) == float else False)
#      23         df['out_y_coord_match'] = np.where(np.isnan(df['input_y_coord']) or np.isnan(df['tgaz_y_coord']), 'NaN', df['input_y_coord'].map(lambda y: round(y)) == df['tgaz_y_coord'].map(lambda y: round(y)))
#
# /home/sf/anaconda3/lib/python3.5/site-packages/pandas/core/series.py in __getitem__(self, key)
#     581         key = com._apply_if_callable(key, self)
#     582         try:
# --> 583             result = self.index.get_value(self, key)
#     584
#     585             if not lib.isscalar(result):
#
# /home/sf/anaconda3/lib/python3.5/site-packages/pandas/indexes/base.py in get_value(self, series, key)
#    1978         try:
#    1979             return self._engine.get_value(s, k,
# -> 1980                                           tz=getattr(series.dtype, 'tz', None))
#    1981         except KeyError as e1:
#    1982             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_value (pandas/index.c:3332)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_value (pandas/index.c:3035)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.Int64HashTable.get_item (pandas/hashtable.c:6610)()
#
# pandas/hashtable.pyx in pandas.hashtable.Int64HashTable.get_item (pandas/hashtable.c:6554)()
#
# KeyError: 3

# %%
# converting all fields to strings for ease of comparison
for field in list(df.columns):
    df[field] = df[field].astype(str)

# %%
# in-row match testing
df['out_beg_match'] = df['input_year_beg'] == df['tgaz_beg']
df['out_end_match'] = df['input_year_end'] == df['tgaz_end']
# Out:
#       tgaz_seq tgaz_sys_id tgaz_data_source      tgaz_nm_py tgaz_nm_simp  \
# 24         5.0       hvd_5            CHGIS          Quyang          曲阳县
# 25     15641.0   hvd_42875            CHGIS     Quyang Xian          曲阳县
# 26     15643.0   hvd_42877            CHGIS     Quyang Xian          曲阳县
# 27     15644.0   hvd_42878            CHGIS   Quyang Houguo         曲阳侯国
# 28     15645.0   hvd_42879            CHGIS     Quyang Xian          曲阳县
# 29     15866.0   hvd_43128            CHGIS   Quyang Houguo         曲阳侯国
# 30     17530.0   hvd_44819            CHGIS     Quyang Xian          曲阳县
# 31     17532.0   hvd_44821            CHGIS     Quyang Xian          曲阳县
# 32     17533.0   hvd_44822            CHGIS     Quyang Xian          曲阳县
# 33     33713.0  hvd_121394            CHGIS     Quyang Xian          曲阳县
# 34     38428.0  hvd_128084            CHGIS      Quyangping          曲阳坪
# 35     43981.0  hvd_133637            CHGIS        Quyangji          曲阳集
# 36     76398.0  hvd_196627            CHGIS     Quyang Xian          曲阳县
# 46         7.0       hvd_7            CHGIS            Wuyi          武邑县
# 47     17596.0   hvd_44885            CHGIS       Wuyi Xian          武邑县
# 48     22403.0   hvd_87204            CHGIS       Wuyi Xian          武邑县
# 49     22405.0   hvd_87206            CHGIS       Wuyi Xian          武邑县
# 50     23101.0   hvd_88093            CHGIS       Wuyi Xian          武邑县
# 51     33773.0  hvd_121454            CHGIS       Wuyi Xian          武邑县
# 52     76375.0  hvd_196604            CHGIS       Wuyi Xian          武邑县
# 53         8.0       hvd_8            CHGIS         Nangong          南宫县
# 54     17591.0   hvd_44880            CHGIS    Nangong Xian          南宫县
# 55     22406.0   hvd_87207            CHGIS    Nangong Xian          南宫县
# 56     22408.0   hvd_87209            CHGIS    Nangong Xian          南宫县
# 57     23098.0   hvd_88082            CHGIS    Nangong Xian          南宫县
# 58     33770.0  hvd_121451            CHGIS    Nangong Xian          南宫县
# 59     45185.0  hvd_134841            CHGIS     Nangongjing          南宫井
# 60     76370.0  hvd_196599            CHGIS    Nangong Xian          南宫县
# 96        12.0      hvd_12            CHGIS         Raoyang          饶阳县
# 97      6569.0   hvd_19785            CHGIS  Raoyangshuibao         饶阳水堡
# ...        ...         ...              ...             ...          ...
# 78316      nan         nan              nan             nan          nan
# 78317      nan         nan              nan             nan          nan
# 78318      nan         nan              nan             nan          nan
# 78319      nan         nan              nan             nan          nan
# 78320      nan         nan              nan             nan          nan
# 78321      nan         nan              nan             nan          nan
# 78322      nan         nan              nan             nan          nan
# 78323      nan         nan              nan             nan          nan
# 78324      nan         nan              nan             nan          nan
# 78324      ...       KPHWBSH00Z02AA      幽州刺史部                      126.174
# 78325      ...       KPHWBSR00Z05AA      幽州刺史部                     125.7711
# 78326      ...       KPHWNSI00Z01AA      幽州刺史部                     125.4346
# 78327      ...       KPHWNUR00Z01AA      幽州刺史部                     125.2003
# 78328      ...       KPPYBPC00Z02AA      幽州刺史部                     125.6226
# 78329      ...       KPPYNAJ00Z01AA      幽州刺史部                     125.6406
# 78330      ...       KPPYNKS00Z03AA      幽州刺史部                     125.3361
# 78331      ...       KPPYNRG00Z03AA      幽州刺史部                     125.3543
# 78332      ...       KPPYORR00Z06AA      幽州刺史部                     125.7221
# 78333      ...       VNB15TH00Z03AA      交州刺史部                     105.5792
# 78334      ...       VNB56BN00Z05AA      交州刺史部                     106.1001
# 78335      ...       VNB64DA00Z01AA      交州刺史部                     105.7783
# 78336      ...       VNB66VG00Z01AA      交州刺史部                     105.8943
# 78337      ...       VNB70ML00Z01AA      交州刺史部                     105.7624
# 78338      ...       VNB70ML00Z05AA      交州刺史部                     105.6568
# 78339      ...       VNB70ML00Z06AA      交州刺史部                     105.7183
# 78340      ...       VNC21HL00Z01AA      交州刺史部                     105.7656
# 78341      ...       VNC21TG00Z01AA      交州刺史部                     105.7052
# 78342      ...       VNC22YT00Z01AA      交州刺史部                     105.4991
# 78343      ...       VNC24QN00Z04AA      交州刺史部                      106.615
# 78344      ...       VNC25TP00Z03AA      交州刺史部                     107.1324
# 78345      ...       VNC26HE00Z02AA      交州刺史部                     107.5677
#
#       input_y_coord      _merge out_x_coord_match out_y_coord_match  \
# 24          34.0994        both             False             False
# 25          34.0994        both             False              True
# 26          34.0994        both             False              True
# 27          34.0994        both             False              True
# 28          34.0994        both             False              True
# 29          34.0994        both             False             False
# 30          34.0994        both             False             False
# 31          34.0994        both             False             False
# 32          34.0994        both             False             False
# 33          34.0994        both             False             False
# 34          34.0994        both             False             False
# 35          34.0994        both             False             False
# 36          34.0994        both             False             False
# 46          37.8052        both              True              True
# 47          37.8052        both              True              True
# 48          37.8052        both              True              True
# 49          37.8052        both              True              True
# 50          37.8052        both              True              True
# 51          37.8052        both              True              True
# 52          37.8052        both             False              True
# 53          37.3778        both              True              True
# 54          37.3778        both              True              True
# 55          37.3778        both              True              True
# 56          37.3778        both              True              True
# 57          37.3778        both              True              True
# 58          37.3778        both              True              True
# 59          37.3778        both             False             False
# 60          37.3778        both             False              True
# 96          38.2956        both              True              True
# 97          38.2956        both             False             False
# ...             ...         ...               ...               ...
# 78316       35.7784  right_only             False             False
# 78317       35.7014  right_only             False             False
# 78318       42.0031  right_only             False             False
# 78319        39.022  right_only             False             False
# 78320       41.7175  right_only             False             False
# 78321       36.8876  right_only             False             False
# 78322         38.02  right_only             False             False
# 78323       38.6948  right_only             False             False
# 78324       38.4702  right_only             False             False
# 78325       38.4701  right_only             False             False
# 78326       38.3249  right_only             False             False
# 78327       38.5243  right_only             False             False
# 78328       39.6732  right_only             False             False
# 78329       39.5349  right_only             False             False
# 78330       38.9745  right_only             False             False
# 78331       38.8494  right_only             False             False
# 78332       38.9596  right_only             False             False
# 78333       21.0733  right_only             False             False
# 78334       21.1113  right_only             False             False
# 78335       21.0641  right_only             False             False
# 78336       20.8585  right_only             False             False
# 78337       21.1332  right_only             False             False
# 78338       21.1843  right_only             False             False
# 78339       21.1922  right_only             False             False
# 78340       19.9404  right_only             False             False
# 78341       19.5432  right_only             False             False
# 78342       18.9846  right_only             False             False
# 78343       17.3565  right_only             False             False
# 78344        16.773  right_only             False             False
# 78345       16.5016  right_only             False             False
#
#       out_beg_match out_end_match
# 24            False         False
# 25            False         False
# 26            False         False
# 27            False         False
# 28            False         False
# 29            False         False
# 30            False         False
# 31            False         False
# 32            False         False
# 33            False         False
# 34            False         False
# 35            False         False
# 36            False         False
# 46            False         False
# 47            False         False
# 48            False         False
# 49            False         False
# 50            False         False
# 51            False         False
# 52            False         False
# 53            False         False
# 54            False         False
# 55            False         False
# 56            False         False
# 57            False         False
# 58            False         False
# 59            False         False
# 60            False         False
# 96            False         False
# 97            False         False
# ...             ...           ...
# 78316         False         False
# 78317         False         False
# 78318         False         False
# 78319         False         False
# 78320         False         False
# 78321         False         False
# 78322         False         False
# 78323         False         False
# 78324         False         False
# 78325         False         False
# 78326         False         False
# 78327         False         False
# 78328         False         False
# 78329         False         False
# 78330         False         False
# 78331         False         False
# 78332         False         False
# 78333         False         False
# 78334         False         False
# 78335         False         False
# 78336         False         False
# 78337         False         False
# 78338         False         False
# 78339         False         False
# 78340         False         False
# 78341         False         False
# 78342         False         False
# 78343         False         False
# 78344         False         False
# 78345         False         False
#
# [6876 rows x 37 columns]

# %%
# adding the 'match_strength' column
df['out_content_match_strength'] = df['out_x_coord_match'].astype(int) + df['out_y_coord_match'].astype(int) + df['out_beg_match'].astype(int) + df['out_end_match'].astype(int)

# %%
# sorting columns
tgaz_fields = [
    'tgaz_sys_id',
    'tgaz_nm_py',
    'tgaz_nm_simp',
    'tgaz_nm_trad',
    'tgaz_beg',
    'tgaz_end',
    'tgaz_data_source',
    'tgaz_obj_type',
    'tgaz_pres_loc',
    'tgaz_prnt_id',
    'tgaz_prnt_py',
    'tgaz_prnt_simp',
    'tgaz_prnt_sysid',
    'tgaz_type_ch',
    'tgaz_type_py',
    'tgaz_x_coord',
    'tgaz_y_coord'
]

ordered_fields = tgaz_fields + input_fields + ['_merge'] + ['out_x_coord_match'] + ['out_y_coord_match'] + ['out_beg_match'] + ['out_end_match'] + ['out_content_match_strength']
fuzzy_ordered_fields = ['fuzzy_nm'] + ordered_fields

if mode == 'strict':
    df = df[ordered_fields]
else:
    df = df[fuzzy_ordered_fields]

# %%
# replacing 'nan' with '' for improved legibility
df = df.replace('nan', '')

# %%
# outputting results
print('\nData check is complete.  Please input the path (with file extension) to which you want to write the results:\n')
output_path = input()

while not output_path.endswith('.csv'):
        print("Filename does not end in .csv -- please try again or use Ctrl-C to exit:")
        output_path = input()

df.to_csv(output_path)

print('File created at %s.  Now exiting.' % output_path)
# Out:
# Data check is complete.  Please input the path (with file extension) to which you want to write the results:
#
# 160904test1.csv
# File created at 160904test1.csv.  Now exiting.
