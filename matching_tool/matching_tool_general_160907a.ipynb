# %%
#! /usr/bin/python3

# Script for comparing an input .csv file with an existing .csv file (e.g. the current CHGIS).
# Indicates 1) matches on name and 2) strength of match on content
# Requires the library 'pandas' to be installed, which is included in Anaconda's free Python distribution

# by Stephen Ford (stephen.p.ford@gmail.com)

import pandas as pd
import os.path

# suppressing SettingWithCopyWarning
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# function for selecting .csv files for manipulation

def csv_picker():
    ''' Function for checking whether user input path 1) is that of a valid file, and 2) is of a file ending with '.csv'
        Prompts for re-entry if entry is invalid.
        Returns a pandas DataFrame constructed from the valid .csv file
    '''
    name = input()

    # checking that the path is a valid filename, and prompting for re-entry if not
    while not (os.path.isfile(name)):
        print("Not a valid filename.  Please try again:")
        name = input()
        
    # checking that the valid filename ends in .csv, prompting for re-entry if not
    while not name.endswith('.csv'):
        print("Filename does not end in .csv -- please try again:")
        name = input()

    print("\nThank you -- filename %s is valid.\n" % name)       
    return pd.read_csv(name, low_memory=False)

# %%
# soliciting files for comparison; presumption is that second file entered will be the CHGIS v5 in .csv format
print("Please input the path of the .csv file (with extension) you wish to compare with the CHGIS:")
new_data = csv_picker()
# /home/sf/chgis/input/sample_data/Donghan_2014-10-02_copy.csv
# /home/sf/chgis/input/sample_data/lexdata.txt.data.csv

print("Please input the path of the .csv file (with extension) containing CHGIS data (script expects v5, or at least its column names):")
chgis = csv_picker()
# /home/sf/chgis/input/v5_augment_2016-08-09.csv
# Out:
# Please input the path of the .csv file (with extension) you wish to compare with the CHGIS:
# /home/sf/chgis/input/sample_data/lexdata.txt.data.csv
#
# Thank you -- filename /home/sf/chgis/input/sample_data/lexdata.txt.data.csv is valid.
#
# Please input the path of the .csv file (with extension) containing CHGIS data (script expects v5, or at least its column names):
# /home/sf/chgis/input/v5_augment_2016-08-09.csv
#
# Thank you -- filename /home/sf/chgis/input/v5_augment_2016-08-09.csv is valid.

# %%
# initializing list of input_fields (i.e. normalized input fields, called "input_*" in final output)
input_fields = []

# function for mapping the input .csv's fields to the desired, standardized output fields
def field_mapper(normalized_field, frame=new_data, fields=input_fields):
    ''' Function that will prompt user to manually map fields of the input .csv to standardized output fields.
        Name changes will be made in-place (i.e. in the DataFrame -- the .csv will be untouched).
        If user fails to enter anything for the given mapping, the output field will be present in the output 
        file, but have no values.        
    '''
    
    print("\nPlease enter the field in the incoming non-CHGIS .csv that will be labeled '%s' in the output .csv:" % normalized_field)
    orig_field = input()
    
    # prompts for re-entering the input field if 1) it is not one of the column names and 2) it isn't an empty string
    while (not orig_field in list(new_data.columns.values)) and (orig_field):
        print("\nNot a valid column name.  Please try again:")
        orig_field = input()
        
    # simply exit if the user pressed enter, bypassing the mapping, or perform the mapping if a valid field name has been entered
    if orig_field:
        frame.rename(columns={orig_field:normalized_field}, inplace=True)
        fields += [normalized_field]
    return fields

# %%
# declaring the list of output .csv field names that will derive from the new data
# i.e., all those fields whose names will be 'input_*' in the final .csv

normalized_fields = [   
    'input_id',
    'input_nm_py',
    'input_nm_simp',
    'input_nm_trad',
    'input_type',
    'input_year_beg',
    'input_year_end',
    'input_dynasty',
    'input_other_id',
    'input_prnt',
    'input_obj_type',
    'input_x_coord',
    'input_y_coord'
]

# %%
# renaming fields in the new data DataFrame to conform to specifications

for field in normalized_fields:
    input_fields = field_mapper(field)
# Out:
# Please enter the field in the incoming non-CHGIS .csv that will be labeled 'input_id' in the output .csv:
# id
#
# Please enter the field in the incoming non-CHGIS .csv that will be labeled 'input_nm_py' in the output .csv:
#
#
# Please enter the field in the incoming non-CHGIS .csv that will be labeled 'input_nm_simp' in the output .csv:
#
#
# Please enter the field in the incoming non-CHGIS .csv that will be labeled 'input_nm_trad' in the output .csv:
# name
#
# Please enter the field in the incoming non-CHGIS .csv that will be labeled 'input_type' in the output .csv:
# level
#
# Please enter the field in the incoming non-CHGIS .csv that will be labeled 'input_year_beg' in the output .csv:
# start
#
# Please enter the field in the incoming non-CHGIS .csv that will be labeled 'input_year_end' in the output .csv:
# end
#
# Please enter the field in the incoming non-CHGIS .csv that will be labeled 'input_dynasty' in the output .csv:
# dynasty
#
# Please enter the field in the incoming non-CHGIS .csv that will be labeled 'input_other_id' in the output .csv:
# oldid
#
# Please enter the field in the incoming non-CHGIS .csv that will be labeled 'input_prnt' in the output .csv:
# Shu
#
# Please enter the field in the incoming non-CHGIS .csv that will be labeled 'input_obj_type' in the output .csv:
#
#
# Please enter the field in the incoming non-CHGIS .csv that will be labeled 'input_x_coord' in the output .csv:
# JingDu
#
# Please enter the field in the incoming non-CHGIS .csv that will be labeled 'input_y_coord' in the output .csv:
# WeuDu

# %%
# storing to avoid having to reenter stuff later
#han_new_data = new_data
#han_input_fields = input_fields
#han_chgis = chgis

lex_new_data = new_data
lex_input_fields = input_fields
lex_chgis = chgis

# %%
# only execute to restore from stored data
#new_data = han_new_data
#input_fields = han_input_fields
#chgis = han_chgis

#new_data = lex_new_data
#input_fields = lex_input_fields
#chgis = lex_chgis

# %%
# dropping all fields from the new_data DataFrame that won't be in final output
new_data = new_data[input_fields]

# dropping fields from the new_data DataFrame that weren't mapped
#for field in new_data.columns:
#    if new_data[field].empty:
#        new_data.drop(field, inplace=True)
#        input_fields.remove(field)
        
print("input_fields are: %s" % str(input_fields))
print("new_data cols are: %s" % str(new_data.columns))
# Out:
# input_fields are: ['input_id', 'input_nm_trad', 'input_type', 'input_year_beg', 'input_year_end', 'input_dynasty', 'input_other_id', 'input_prnt', 'input_x_coord', 'input_y_coord']
# new_data cols are: Index(['input_id', 'input_nm_trad', 'input_type', 'input_year_beg',
#        'input_year_end', 'input_dynasty', 'input_other_id', 'input_prnt',
#        'input_x_coord', 'input_y_coord'],
#       dtype='object')

# %%
# manually renaming one exception to the following pattern
chgis.rename(columns={'src':'data_source'}, inplace=True)

# renaming the CHGIS fields in-place to conform to output specifications
chgis.columns = ['tgaz_%s' % x for x in chgis.columns]

# %%
# offering user choice of strict or fuzzy name-matching

def merge_chooser():
    ''' Function called only if the user selects to merge on traditional characters 繁體字 or simplified characters 简体字
        Lets user choose whether to do a strict or fuzzy merge.
        In a fuzzy merge, only the first two characters of the Chinese names will be checked against one another.
    '''
    print(
    '''
Please indicate, by entering a numerical digit 1-2, whether you wish to do a strict or fuzzy match of names:
    1. Strict matching (e.g. '張掖' matches '張掖', but '張掖' does not match '張掖居延屬國')
    2. Fuzzy matching (e.g. '張掖' matches '張掖', and '張掖' also matches '張掖居延屬國')
    ''')

    accepted = False
    choice = input()

    while accepted == False:
        if choice == '1':
            print('Proceeding with strict matching of names.')
            accepted = True
            mode = 'strict'
            df = chgis.merge(new_data, how='outer', left_on=chgis_name_match_field, right_on=input_name_match_field, indicator=True)
            return df, mode
        elif choice == '2':
            print('Proceeding with fuzzy matching of names.')
            accepted = True
            mode = 'fuzzy'
            chgis['fuzzy_nm'] = chgis[chgis_name_match_field].map(lambda x: x[:2])
            new_data['fuzzy_nm'] = new_data[input_name_match_field].map(lambda x: x[:2])
            df = chgis.merge(new_data, how='outer', on='fuzzy_nm', indicator=True)
            return df, mode
        else:
            print("\nNot a valid response.  Please try again:\n")
            choice = input()

# %%
# initializing list of tgaz fields
tgaz_fields = [
    'tgaz_sys_id',
    'tgaz_nm_py',
    'tgaz_nm_simp',
    'tgaz_nm_trad',
    'tgaz_beg',
    'tgaz_end',
    'tgaz_data_source',
    'tgaz_obj_type',
    'tgaz_pres_loc',
    'tgaz_prnt_id',
    'tgaz_prnt_py',
    'tgaz_prnt_simp',
    'tgaz_prnt_sysid',
    'tgaz_type_ch',
    'tgaz_type_py',
    'tgaz_x_coord',
    'tgaz_y_coord'
]

# %%
# soliciting user choice regarding which name field to take as primary
#print(input_fields)

print(
    '''
Thank you. Now, please indicate, by entering a numerical digit 1-3, which of the following names you wish to make the primary key for comparing data:
    1. Name in complex/traditional Chinese characters 繁体字
    2. Name in simplified Chinese characters 简体字
    3. Name in pinyin 拼音
    '''
)

accepted = False
choice = input()

while accepted == False:
    if ((choice == '1') and ('input_nm_trad' in input_fields)):
        print("\nUsing name in complex/traditional Chinese characters 繁体字 as primary matching key.")
        accepted = True
        input_name_match_field = 'input_nm_trad'
        chgis_name_match_field = 'tgaz_nm_trad'
        output_name_match_field = 'out_nm_trad_match'
        df, name_mode = merge_chooser()
        output_fields = [output_name_match_field]        
    elif ((choice == '2') and ('input_nm_simp' in input_fields)):
        print("\nUsing name in simplified Chinese characters 简体字 as primary matching key.")
        accepted = True
        input_name_match_field = 'input_nm_simp'
        chgis_name_match_field = 'tgaz_nm_simp'
        output_name_match_field = 'out_nm_simp_match'
        df, name_mode = merge_chooser()
        output_fields = [output_name_match_field]
    elif ((choice == '3') and ('input_nm_py' in input_fields)):
        print("\nUsing name in pinyin 拼音 as primary matching key.")
        accepted = True
        input_name_match_field = 'input_nm_py'
        chgis_name_match_field = 'tgaz_nm_py'
        output_name_match_field = 'out_nm_py_match'
        name_mode = 'strict'
        print('Fuzzy matching is not currently supported for pinyin names.  Proceeding with strict matching.')
        df = chgis.merge(new_data, how='outer', left_on=chgis_name_match_field, right_on=input_name_match_field, indicator=True)
        output_fields = [output_name_match_field]

    else:
        print("\nNot a valid response.  Please try again, entering a choice corresponding to a valid field:\n")
        choice = input()
        
print(output_fields)
# Out:
# Thank you. Now, please indicate, by entering a numerical digit 1-3, which of the following names you wish to make the primary key for comparing data:
#     1. Name in complex/traditional Chinese characters 繁体字
#     2. Name in simplified Chinese characters 简体字
#     3. Name in pinyin 拼音
#
# 2
#
# Not a valid response.  Please try again, entering a choice corresponding to a valid field:
#
# 1
#
# Using name in complex/traditional Chinese characters 繁体字 as primary matching key.
#
# Please indicate, by entering a numerical digit 1-2, whether you wish to do a strict or fuzzy match of names:
#     1. Strict matching (e.g. '張掖' matches '張掖', but '張掖' does not match '張掖居延屬國')
#     2. Fuzzy matching (e.g. '張掖' matches '張掖', and '張掖' also matches '張掖居延屬國')
#
# 2
# Proceeding with fuzzy matching of names.
# ['out_nm_trad_match']

# %%
#### Abandoning comprehensive for-loop for sake of year matching; manually stringifying coords instead

# converting all fields to strings for ease of comparison
#for field in list(df.columns):
#    df[field] = df[field].astype(str)
spatial_coords = ['input_x_coord', 'input_y_coord', 'tgaz_x_coord', 'tgaz_y_coord']
for field in spatial_coords:
    if (field in input_fields) or (field in tgaz_fields):
        df[field] = df[field].astype(str)

# %%
# removing rows that are only present in the CHGIS file
df = df[df['_merge'] != 'left_only']
df
# Out:
#         tgaz_seq tgaz_sys_id tgaz_data_source     tgaz_nm_py tgaz_nm_simp  \
# 0            1.0       hvd_1            CHGIS        Ba Zhou           霸州
# 1            1.0       hvd_1            CHGIS        Ba Zhou           霸州
# 2            1.0       hvd_1            CHGIS        Ba Zhou           霸州
# 3        23170.0   hvd_88200            CHGIS        Ba Zhou           霸州
# 4        23170.0   hvd_88200            CHGIS        Ba Zhou           霸州
# 5        23170.0   hvd_88200            CHGIS        Ba Zhou           霸州
# 6        29392.0  hvd_110624            CHGIS        Ba Zhou           霸州
# 7        29392.0  hvd_110624            CHGIS        Ba Zhou           霸州
# 8        29392.0  hvd_110624            CHGIS        Ba Zhou           霸州
# 9        33824.0  hvd_121505            CHGIS        Ba Zhou           霸州
# 10       33824.0  hvd_121505            CHGIS        Ba Zhou           霸州
# 11       33824.0  hvd_121505            CHGIS        Ba Zhou           霸州
# 12       76437.0  hvd_196666            CHGIS        Ba Zhou           霸州
# 13       76437.0  hvd_196666            CHGIS        Ba Zhou           霸州
# 14       76437.0  hvd_196666            CHGIS        Ba Zhou           霸州
# 19           3.0       hvd_3            CHGIS       Dingxing          定兴县
# 20           3.0       hvd_3            CHGIS       Dingxing          定兴县
# 21       22844.0   hvd_87673            CHGIS  Dingxing Xian          定兴县
# 22       22844.0   hvd_87673            CHGIS  Dingxing Xian          定兴县
# 23       33784.0  hvd_121465            CHGIS  Dingxing Xian          定兴县
# 24       33784.0  hvd_121465            CHGIS  Dingxing Xian          定兴县
# 25       45693.0  hvd_135349            CHGIS    Dingxingbao          定兴堡
# 26       45693.0  hvd_135349            CHGIS    Dingxingbao          定兴堡
# 27       76388.0  hvd_196617            CHGIS  Dingxing Xian          定兴县
# 28       76388.0  hvd_196617            CHGIS  Dingxing Xian          定兴县
# 29           4.0       hvd_4            CHGIS         Shenze          深泽县
# 30           4.0       hvd_4            CHGIS         Shenze          深泽县
# 31           4.0       hvd_4            CHGIS         Shenze          深泽县
# 32           4.0       hvd_4            CHGIS         Shenze          深泽县
# 33           4.0       hvd_4            CHGIS         Shenze          深泽县
# ...          ...         ...              ...            ...          ...
# 204080       NaN         NaN              NaN            NaN          NaN
# 204081       NaN         NaN              NaN            NaN          NaN
# 204082       NaN         NaN              NaN            NaN          NaN
# 204083       NaN         NaN              NaN            NaN          NaN
# 204084       NaN         NaN              NaN            NaN          NaN
# 204085       NaN         NaN              NaN            NaN          NaN
# 204086       NaN         NaN              NaN            NaN          NaN
# 204087       NaN         NaN              NaN            NaN          NaN
# 204088       NaN         NaN              NaN            NaN          NaN
# 204089       NaN         NaN              NaN            NaN          NaN
# 204090       NaN         NaN              NaN            NaN          NaN
# 204091       NaN         NaN              NaN            NaN          NaN
# 204092       NaN         NaN              NaN            NaN          NaN
# 204093       NaN         NaN              NaN            NaN          NaN
# 204094       NaN         NaN              NaN            NaN          NaN
# 204095       NaN         NaN              NaN            NaN          NaN
# 204096       NaN         NaN              NaN            NaN          NaN
# 204097       NaN         NaN              NaN            NaN          NaN
# 204098       NaN         NaN              NaN            NaN          NaN
# 204099       NaN         NaN              NaN            NaN          NaN
# 204100       NaN         NaN              NaN            NaN          NaN
# 204101       NaN         NaN              NaN            NaN          NaN
# 204102       NaN         NaN              NaN            NaN          NaN
# 204103       NaN         NaN              NaN            NaN          NaN
# 204104       NaN         NaN              NaN            NaN          NaN
# 204105       NaN         NaN              NaN            NaN          NaN
# 204106       NaN         NaN              NaN            NaN          NaN
# 204107       NaN         NaN              NaN            NaN          NaN
# 204108       NaN         NaN              NaN            NaN          NaN
# 204109       NaN         NaN              NaN            NaN          NaN
#
#        tgaz_nm_trad tgaz_x_coord tgaz_y_coord tgaz_pres_loc tgaz_type_py  \
# 0                霸州    116.39525     39.10154          河北霸县         zhou
# 1                霸州    116.39525     39.10154          河北霸县         zhou
# 2                霸州    116.39525     39.10154          河北霸县         zhou
# 3                霸州    116.39525     39.10154         今河北霸县         zhou
# 4                霸州    116.39525     39.10154         今河北霸县         zhou
# 5                霸州    116.39525     39.10154         今河北霸县         zhou
# 6                霸州    106.55871     29.56005         重庆市区东         zhou
# 7                霸州    106.55871     29.56005         重庆市区东         zhou
# 8                霸州    106.55871     29.56005         重庆市区东         zhou
# 9                霸州    116.39525     39.10154        河北霸州县治         zhou
# 10               霸州    116.39525     39.10154        河北霸州县治         zhou
# 11               霸州    116.39525     39.10154        河北霸州县治         zhou
# 12               霸州          0.0     39.10154           NaN         zhou
# 13               霸州          0.0     39.10154           NaN         zhou
# 14               霸州          0.0     39.10154           NaN         zhou
# 19              定興縣    115.77419     39.26959         河北定兴县         xian
# 20              定興縣    115.77419     39.26959         河北定兴县         xian
# 21              定興縣    115.77419     39.26959  今河北省定兴县驻地定兴镇         xian
# 22              定興縣    115.77419     39.26959  今河北省定兴县驻地定兴镇         xian
# 23              定興縣    115.77419     39.26959        河北定兴县治         xian
# 24              定興縣    115.77419     39.26959        河北定兴县治         xian
# 25              定興堡    115.02703     40.69147      河北宣化县定兴堡     cun zhen
# 26              定興堡    115.02703     40.69147      河北宣化县定兴堡     cun zhen
# 27              定興縣          0.0     39.26959           NaN         xian
# 28              定興縣          0.0     39.26959           NaN         xian
# 29              深澤縣    115.19209      38.1849         河北深泽县         xian
# 30              深澤縣    115.19209      38.1849         河北深泽县         xian
# 31              深澤縣    115.19209      38.1849         河北深泽县         xian
# 32              深澤縣    115.19209      38.1849         河北深泽县         xian
# 33              深澤縣    115.19209      38.1849         河北深泽县         xian
# ...             ...          ...          ...           ...          ...
# 204080          NaN          nan          nan           NaN          NaN
# 204081          NaN          nan          nan           NaN          NaN
# 204082          NaN          nan          nan           NaN          NaN
# 204083          NaN          nan          nan           NaN          NaN
# 204084          NaN          nan          nan           NaN          NaN
# 204085          NaN          nan          nan           NaN          NaN
# 204086          NaN          nan          nan           NaN          NaN
# 204087          NaN          nan          nan           NaN          NaN
# 204088          NaN          nan          nan           NaN          NaN
# 204089          NaN          nan          nan           NaN          NaN
# 204090          NaN          nan          nan           NaN          NaN
# 204091          NaN          nan          nan           NaN          NaN
# 204092          NaN          nan          nan           NaN          NaN
# 204093          NaN          nan          nan           NaN          NaN
# 204094          NaN          nan          nan           NaN          NaN
# 204095          NaN          nan          nan           NaN          NaN
# 204096          NaN          nan          nan           NaN          NaN
# 204097          NaN          nan          nan           NaN          NaN
# 204098          NaN          nan          nan           NaN          NaN
# 204099          NaN          nan          nan           NaN          NaN
# 204100          NaN          nan          nan           NaN          NaN
# 204101          NaN          nan          nan           NaN          NaN
# 204102          NaN          nan          nan           NaN          NaN
# 204103          NaN          nan          nan           NaN          NaN
# 204104          NaN          nan          nan           NaN          NaN
# 204105          NaN          nan          nan           NaN          NaN
# 204106          NaN          nan          nan           NaN          NaN
# 204107          NaN          nan          nan           NaN          NaN
# 204108          NaN          nan          nan           NaN          NaN
# 204109          NaN          nan          nan           NaN          NaN
#
#            ...     input_nm_trad  input_type  input_year_beg input_year_end  \
# 0          ...                霸州           府             960           1127
# 1          ...                霸州           縣            1368           1644
# 2          ...                霸州           府             907            979
# 3          ...                霸州           府             960           1127
# 4          ...                霸州           縣            1368           1644
# 5          ...                霸州           府             907            979
# 6          ...                霸州           府             960           1127
# 7          ...                霸州           縣            1368           1644
# 8          ...                霸州           府             907            979
# 9          ...                霸州           府             960           1127
# 10         ...                霸州           縣            1368           1644
# 11         ...                霸州           府             907            979
# 12         ...                霸州           府             960           1127
# 13         ...                霸州           縣            1368           1644
# 14         ...                霸州           府             907            979
# 19         ...                定興           縣            1368           1644
# 20         ...                定興           縣            1271           1368
# 21         ...                定興           縣            1368           1644
# 22         ...                定興           縣            1271           1368
# 23         ...                定興           縣            1368           1644
# 24         ...                定興           縣            1271           1368
# 25         ...                定興           縣            1368           1644
# 26         ...                定興           縣            1271           1368
# 27         ...                定興           縣            1368           1644
# 28         ...                定興           縣            1271           1368
# 29         ...                深澤           縣             960           1127
# 30         ...                深澤           縣            1368           1644
# 31         ...                深澤           縣             581            618
# 32         ...                深澤           縣             618            907
# 33         ...                深澤           縣         Err:512             24
# ...        ...               ...         ...             ...            ...
# 204080     ...               剌客寨           縣            1271           1368
# 204081     ...               小繳州           縣            1271           1368
# 204082     ...               繳那州           縣            1271           1368
# 204083     ...                林種           縣            1271           1368
# 204084     ...               繳來州           縣            1271           1368
# 204085     ...               北島州           縣            1271           1368
# 204086     ...               小葛龍           縣            1271           1368
# 204087     ...                黨兀           縣            1271           1368
# 204088     ...                邑市           縣            1271           1368
# 204089     ...                邵甸           縣            1271           1368
# 204090     ...                歸厚           縣            1271           1368
# 204091     ...                為美           縣            1271           1368
# 204092     ...               仁德府           縣            1271           1368
# 204093     ...                芳華           縣            1271           1368
# 204094     ...                河納           縣            1271           1368
# 204095     ...                交水           縣            1271           1368
# 204096     ...                普舍           縣            1271           1368
# 204097     ...               益良州           縣            1271           1368
# 204098     ...               繳陀部           縣            1271           1368
# 204099     ...            普日思摩甸司           縣            1271           1368
# 204100     ...               伴溪部           縣            1271           1368
# 204101     ...               七溪部           縣            1271           1368
# 204102     ...               普騰部           縣            1271           1368
# 204103     ...               薩斯迦           縣            1271           1368
# 204104     ...                鐸水           縣            1271           1368
# 204105     ...                涇川           縣            1271           1368
# 204106     ...           禮店文州元帥府           縣            1271           1368
# 204107     ...                可當           縣            1271           1368
# 204108     ...                闍?           縣            1271           1368
# 204109     ...               叉力失           縣            1271           1368
#
#        input_dynasty  input_other_id input_prnt input_x_coord input_y_coord  \
# 0                 北宋  CN0131081Z09AA       河北東路       116.405       39.1007
# 1                  明  CN0131081Z07AA         京師       116.405       39.1007
# 2               五代十國  CN0211302Z18AA          遼      120.4632       41.5867
# 3                 北宋  CN0131081Z09AA       河北東路       116.405       39.1007
# 4                  明  CN0131081Z07AA         京師       116.405       39.1007
# 5               五代十國  CN0211302Z18AA          遼      120.4632       41.5867
# 6                 北宋  CN0131081Z09AA       河北東路       116.405       39.1007
# 7                  明  CN0131081Z07AA         京師       116.405       39.1007
# 8               五代十國  CN0211302Z18AA          遼      120.4632       41.5867
# 9                 北宋  CN0131081Z09AA       河北東路       116.405       39.1007
# 10                 明  CN0131081Z07AA         京師       116.405       39.1007
# 11              五代十國  CN0211302Z18AA          遼      120.4632       41.5867
# 12                北宋  CN0131081Z09AA       河北東路       116.405       39.1007
# 13                 明  CN0131081Z07AA         京師       116.405       39.1007
# 14              五代十國  CN0211302Z18AA          遼      120.4632       41.5867
# 19                 明  CN0130626Z02AA         京師       115.784       39.2688
# 20                 元  CN0130626Z03AA        中書省       115.784       39.2688
# 21                 明  CN0130626Z02AA         京師       115.784       39.2688
# 22                 元  CN0130626Z03AA        中書省       115.784       39.2688
# 23                 明  CN0130626Z02AA         京師       115.784       39.2688
# 24                 元  CN0130626Z03AA        中書省       115.784       39.2688
# 25                 明  CN0130626Z02AA         京師       115.784       39.2688
# 26                 元  CN0130626Z03AA        中書省       115.784       39.2688
# 27                 明  CN0130626Z02AA         京師       115.784       39.2688
# 28                 元  CN0130626Z03AA        中書省       115.784       39.2688
# 29                北宋  CN0130128Z06AA       河北西路      115.2017       38.1842
# 30                 明  CN0130128Z04AA         京師      115.2017       38.1842
# 31                 隋  CN0130128Z08AA        博陵郡      115.2017       38.1842
# 32                 唐  CN0130128Z07AA        河北道      115.2017       38.1842
# 33                西漢  CN0130128Z09AA      冀州刺史部      115.2017       38.1842
# ...              ...             ...        ...           ...           ...
# 204080             元  CN0522727Z01AA       湖廣行省      107.1508       25.9411
# 204081             元  CN0522727Z12AA       湖廣行省       106.933       25.6885
# 204082             元  CN0522728Z02AA       湖廣行省      106.5893       25.6928
# 204083             元  CN0522728Z06AA       湖廣行省      106.9124       25.4741
# 204084             元  CN0522728Z10AA       湖廣行省      106.7528       25.3795
# 204085             元  CN0522728Z11AA       湖廣行省        106.89       25.3277
# 204086             元  CN0522730Z05AA       湖廣行省      106.9787       26.6381
# 204087             元  CN0522731Z17AA       湖廣行省      106.8243       26.0692
# 204088             元  CN0530125Z02AA       雲南行省      103.1857       24.9923
# 204089             元  CN0530127Z06AA       雲南行省      102.8825       25.3034
# 204090             元  CN0530129Z03AA       雲南行省      102.8215        25.565
# 204091             元  CN0530129Z06AA       雲南行省      103.2617       25.5617
# 204092             元  CN0530129Z07AA       雲南行省      103.2617       25.5617
# 204093             元  CN0530322Z02AA       雲南行省      103.6722       25.1703
# 204094             元  CN0530322Z12AA       雲南行省      103.8256       24.9307
# 204095             元  CN0530328Z03AA       雲南行省      103.8301       25.6094
# 204096             元  CN0530402Z07AA       雲南行省      102.5463       24.4545
# 204097             元  CN0530628Z04AA       雲南行省      104.0584        27.629
# 204098             元  CN0530802Z08AA       雲南行省      100.7323       22.6056
# 204099             元  CN0530821Z07AA       雲南行省       101.045       23.0663
# 204100             元  CN0532529Z10AA       雲南行省       102.237       23.2558
# 204101             元  CN0532529Z12AA       雲南行省      102.4537       23.2356
# 204102             元  CN0532801Z02AA       雲南行省       101.075       22.4166
# 204103             元  CN0542325Z07AA      宣政院轄地       88.0161       28.8998
# 204104             元  CN0610725Z17AA       四川行省      106.6802       33.1561
# 204105             元  CN0620821Z25AA       陝西行省      107.3724       35.3286
# 204106             元  CN0621226Z10AA      宣政院轄地      105.3051       34.2707
# 204107             元  CN0623021Z03AA      宣政院轄地      103.6899       34.7372
# 204108         察合台汗國  CN0652825Z14AA    Err:512       85.2362       37.9893
# 204109             元  CN0652826Z03AA       哈剌火州        86.569       42.0603
#
#             _merge
# 0             both
# 1             both
# 2             both
# 3             both
# 4             both
# 5             both
# 6             both
# 7             both
# 8             both
# 9             both
# 10            both
# 11            both
# 12            both
# 13            both
# 14            both
# 19            both
# 20            both
# 21            both
# 22            both
# 23            both
# 24            both
# 25            both
# 26            both
# 27            both
# 28            both
# 29            both
# 30            both
# 31            both
# 32            both
# 33            both
# ...            ...
# 204080  right_only
# 204081  right_only
# 204082  right_only
# 204083  right_only
# 204084  right_only
# 204085  right_only
# 204086  right_only
# 204087  right_only
# 204088  right_only
# 204089  right_only
# 204090  right_only
# 204091  right_only
# 204092  right_only
# 204093  right_only
# 204094  right_only
# 204095  right_only
# 204096  right_only
# 204097  right_only
# 204098  right_only
# 204099  right_only
# 204100  right_only
# 204101  right_only
# 204102  right_only
# 204103  right_only
# 204104  right_only
# 204105  right_only
# 204106  right_only
# 204107  right_only
# 204108  right_only
# 204109  right_only
#
# [153852 rows x 30 columns]

# %%
def coordinate_matcher(coords, frame=df, fields=output_fields):
    print(
        '''
    Please indicate, by entering a numerical digit 1-2, whether you wish to do a strict or fuzzy match of spatial coordinates:
        1. Strict matching (requires exact match, e.g. '119.64656' does NOT match '119.646560', '119.64657', or '119.325')
        2. Fuzzy matching (only requires that truncated number of whole degrees matches, e.g. '119.64656' DOES match '119.646560', '119.64657', and '119.325')
        ''')

    accepted = False
    choice = input()

    while accepted == False:
        if choice == '1':
            print('Proceeding with strict matching of spatial coordinates.')
            accepted = True
            for coord in coords:
                frame['out_%s_coord_match' % coord] = frame['input_%s_coord' % coord] == frame['tgaz_%s_coord' % coord]
                fields += ['out_%s_coord_match' % coord]
            return "strict"
        elif choice == '2':
            print("Proceeding with fuzzy matching of spatial coordinates.")
            accepted = True
            for coord in coords:
                frame['fuzzy_out_%s_coord_match' % coord] = frame['input_%s_coord' % coord].map(lambda x: x[:3]) == frame['tgaz_%s_coord' % coord].map(lambda x: x[:3])
                fields += ['fuzzy_out_%s_coord_match' % coord]
            return "fuzzy" 
        else:
            print("\nNot a valid response.  Please try again:\n")
            choice = input()

# %%
if ('input_x_coord' in input_fields) and ('input_y_coord' in input_fields):
    coord_mode = coordinate_matcher(['x', 'y'])
elif ('input_x_coord' in input_fields) and not ('input_y_coord' in input_fields):
    coord_mode = coordinate_matcher(['x'])
elif not ('input_x_coord' in input_fields) and ('input_y_coord' in input_fields):
    coord_mode = coordinate_matcher(['y'])
else:
    print("\nNo spatial coordinate fields available for matching.")
# Out:
#     Please indicate, by entering a numerical digit 1-2, whether you wish to do a strict or fuzzy match of spatial coordinates:
#         1. Strict matching (requires exact match, e.g. '119.64656' does NOT match '119.646560', '119.64657', or '119.325')
#         2. Fuzzy matching (only requires that truncated number of whole degrees matches, e.g. '119.64656' DOES match '119.646560', '119.64657', and '119.325')
#
# 2
# Proceeding with fuzzy matching of spatial coordinates.

# %%
#if (df['input_year_beg'].empty() | df['input_year_end'].empty()):
#    if (df['input_year_beg'].empty()):
#        df.drop(['input_year_beg'])
#        input_fields.remove('input_year_beg')
#        beg_year_matching = False
#    if (df['input_year_end'].empty()):
#        df.drop(['input_year_end'])
#        input_fields.remove('input_year_end')
#        end_year_matching = False

if (not 'input_year_beg' in input_fields) or (not 'input_year_end' in input_fields):
    print("Incoming data lacks a beginning and/or ending year field; no date comparisons will be made.")
else:
    beg_year_matching, end_year_matching = True, True
    
    year_fields = ['input_year_beg', 'input_year_end', 'tgaz_beg', 'tgaz_end']
        
    # in-row match testing
    df['out_beg_match'] = df['input_year_beg'] == df['tgaz_beg']
    df['out_end_match'] = df['input_year_end'] == df['tgaz_end']
        
    # overlap field initialization
    df['out_year_overlap'] = ''

    # converting to strings
    for year_field in year_fields:
        df[year_field] = df[year_field].astype(str)

    #print(df['input_year_beg'])
    #print(df['input_year_beg'].dtype)
    
    # masking so as to separate rows with numeric years from those without
    df['all_numeric'] = df['input_year_beg'].str.isnumeric() & df['input_year_end'].str.isnumeric() & df['tgaz_beg'].str.isnumeric() & df['tgaz_end'].str.isnumeric()
    
    # splitting df into n_df (for numeric) and e_df (for error)
    n_df = df[df['all_numeric']]
    e_df = df[~df['all_numeric']]
    
    ### handling numeric sub-DataFrame
        
    # converting back to numerics from strings
    for year_field in year_fields:
        pd.to_numeric(n_df[year_field], errors='coerce')
    print(n_df['input_year_beg'].dtype)
    
    # replacing non-numeric values in the column with 'NaN' to avoid errors in boolean comparisons below
    #pd.to_numeric(df['input_year_beg'], errors='coerce')
    #pd.to_numeric(df['input_year_end'], errors='coerce')
    #pd.to_numeric(df['tgaz_beg'], errors='coerce')
    #pd.to_numeric(df['tgaz_end'], errors='coerce')
    
    # testing for timespan relationships
    n_df['out_year_overlap'][(n_df['all_numeric']) & ((df['input_year_beg'] == (df['tgaz_end'] + 1)) | (df['input_year_end'] == (df['tgaz_beg'] - 1)))] = 'adjacent'
    pythodf['out_year_overlap'][(df['all_numeric']) & (df['input_year_beg'] > df['tgaz_beg']) & (df['input_year_end'] < df['tgaz_end'])] = 'new_nested_in_chgis'
    df['out_year_overlap'][(df['all_numeric']) & (df['input_year_beg'] < df['tgaz_beg']) & (df['input_year_end'] > df['tgaz_end'])] = 'chgis_nested_in_new'
    df['out_year_overlap'][(df['all_numeric']) & (df['input_year_beg'] < df['tgaz_beg']) & (df['input_year_end'] > df['tgaz_beg']) & (df['input_year_end'] < df['tgaz_end'])] = 'partial_incl_start'
    df['out_year_overlap'][(df['all_numeric']) & (df['input_year_beg'] > df['tgaz_beg']) & (df['input_year_beg'] < df['tgaz_end']) & (df['input_year_end'] > df['tgaz_end'])] = 'partial_incl_end'
    df['out_year_overlap'][(df['all_numeric']) & (df['input_year_beg'] == df['tgaz_beg']) & (df['input_year_end'] == df['tgaz_end'])] = 'perfect_match'
    df['out_year_overlap'][(df['all_numeric']) & (df['input_year_beg'] == 0) | (df['input_year_end'] == 0) | (df['tgaz_beg'] == 0) | (df['tgaz_end'] == 0)] = 'CAUTION__ZEROES'
    df['out_year_overlap'][(df['all_numeric']) & (df['input_year_beg'] > df['input_year_end']) | (df['tgaz_beg'] > df['tgaz_end'])] = 'ERROR__END_BEFORE_BEG'
    # df['out_year_overlap'][(df['input_year_beg'].isnull()) | (df['input_year_end'].isnull())] = 'ERROR__NON_NUMERIC_DATA'
    df['out_year_overlap'][~df['all_numeric']] = 'ERROR__NON_NUMERIC_YEAR_VALUE'
    
    output_fields += ['out_beg_match'] + ['out_end_match'] + ['out_year_overlap']
# Out:
# 0             960
# 1            1368
# 2             907
# 3             960
# 4            1368
# 5             907
# 6             960
# 7            1368
# 8             907
# 9             960
# 10           1368
# 11            907
# 12            960
# 13           1368
# 14            907
# 19           1368
# 20           1271
# 21           1368
# 22           1271
# 23           1368
# 24           1271
# 25           1368
# 26           1271
# 27           1368
# 28           1271
# 29            960
# 30           1368
# 31            581
# 32            618
# 33        Err:512
#            ...
# 204080       1271
# 204081       1271
# 204082       1271
# 204083       1271
# 204084       1271
# 204085       1271
# 204086       1271
# 204087       1271
# 204088       1271
# 204089       1271
# 204090       1271
# 204091       1271
# 204092       1271
# 204093       1271
# 204094       1271
# 204095       1271
# 204096       1271
# 204097       1271
# 204098       1271
# 204099       1271
# 204100       1271
# 204101       1271
# 204102       1271
# 204103       1271
# 204104       1271
# 204105       1271
# 204106       1271
# 204107       1271
# 204108       1271
# 204109       1271
# Name: input_year_beg, dtype: object
# object
# object
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/sf/anaconda3/lib/python3.5/site-packages/pandas/core/ops.py in na_op(x, y)
#     581             result = expressions.evaluate(op, str_rep, x, y,
# --> 582                                           raise_on_error=True, **eval_kwargs)
#     583         except TypeError:
#
# /home/sf/anaconda3/lib/python3.5/site-packages/pandas/computation/expressions.py in evaluate(op, op_str, a, b, raise_on_error, use_numexpr, **eval_kwargs)
#     208         return _evaluate(op, op_str, a, b, raise_on_error=raise_on_error,
# --> 209                          **eval_kwargs)
#     210     return _evaluate_standard(op, op_str, a, b, raise_on_error=raise_on_error)
#
# /home/sf/anaconda3/lib/python3.5/site-packages/pandas/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, raise_on_error, truediv, reversed, **eval_kwargs)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b, raise_on_error)
#     121
#
# /home/sf/anaconda3/lib/python3.5/site-packages/pandas/computation/expressions.py in _evaluate_standard(op, op_str, a, b, raise_on_error, **eval_kwargs)
#      61         _store_test_result(False)
# ---> 62     return op(a, b)
#      63
#
# TypeError: Can't convert 'int' object to str implicitly
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-e06d2f27f8f0> in <module>()
#      44
#      45     # testing for timespan relationships
# ---> 46     df['out_year_overlap'][(df['all_numeric']) & ((df['input_year_beg'] == (df['tgaz_end'] + 1)) | (df['input_year_end'] == (df['tgaz_beg'] - 1)))] = 'adjacent'
#      47     pythodf['out_year_overlap'][(df['all_numeric']) & (df['input_year_beg'] > df['tgaz_beg']) & (df['input_year_end'] < df['tgaz_end'])] = 'new_nested_in_chgis'
#      48     df['out_year_overlap'][(df['all_numeric']) & (df['input_year_beg'] < df['tgaz_beg']) & (df['input_year_end'] > df['tgaz_end'])] = 'chgis_nested_in_new'
#
# /home/sf/anaconda3/lib/python3.5/site-packages/pandas/core/ops.py in wrapper(left, right, name, na_op)
#     649                 lvalues = lvalues.values
#     650
# --> 651             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     652                                      index=left.index, name=left.name,
#     653                                      dtype=dtype)
#
# /home/sf/anaconda3/lib/python3.5/site-packages/pandas/core/ops.py in na_op(x, y)
#     590                 result = np.empty(len(x), dtype=x.dtype)
#     591                 mask = notnull(x)
# --> 592                 result[mask] = op(x[mask], y)
#     593             else:
#     594                 raise TypeError("{typ} cannot perform the operation "
#
# TypeError: Can't convert 'int' object to str implicitly

# %%
# adding the 'match_strength' column
df['out_content_match_strength'] = 0
output_fields += ['out_content_match_strength']

if ('input_x_coord' in input_fields):
    if coord_mode == "strict":
        df['out_content_match_strength'] += df['out_x_coord_match'].astype(int)
    else: 
        df['out_content_match_strength'] += df['fuzzy_out_x_coord_match'].astype(int)

if ('input_y_coord' in input_fields):
    if coord_mode == "strict":
        df['out_content_match_strength'] += df['out_y_coord_match'].astype(int)
    else: 
        df['out_content_match_strength'] += df['fuzzy_out_y_coord_match'].astype(int)
    
if ('input_beg_year' in input_fields):
    df['out_content_match_strength'] += df['out_beg_match'].astype(int) 
    
if ('input_end_year' in input_fields):
    df['out_content_match_strength'] += df['out_end_match'].astype(int)

# %%
# sorting columns

ordered_fields = tgaz_fields + input_fields + ['_merge'] + output_fields
print(ordered_fields)
fuzzy_ordered_fields = ['fuzzy_nm'] + ordered_fields

if name_mode == 'strict':
    df = df[ordered_fields]
else:
    df = df[fuzzy_ordered_fields]

# %%
# replacing 'nan' with '' for improved legibility
df = df.replace('nan', '')

# %%
# outputting results
print('\nData check is complete.  Please input the path (with file extension) to which you want to write the results:\n')
output_path = input()

while not output_path.endswith('.csv'):
        print("Filename does not end in .csv -- please try again or use Ctrl-C to exit:")
        output_path = input()

df.to_csv(output_path)

print('File created at %s.  Now exiting.' % output_path)
